# %% [markdown]
# ## ASSIGNMENT NO 3

# %% [markdown]
# ### Question 1:Age Group Classification
#
# Write a Python program that takes the age of a person as input and classifies them into one of the following age groups:
#
# "Child" if the age is between 0 and 12 (inclusive).
#
# "Teenager" if the age is between 13 and 19 (inclusive).
#
# "Adult" if the age is between 20 and 64 (inclusive).
#
# "Senior" if the age is 65 or older.

# %% [markdown]
# ### Scenario 1

# %%
age = int(input("Enter your age: "))

if age >= 0 and age <=12:
  print("CHILD")
elif age >= 13 and age <=19:
  print("TEENAGER")
elif age >=20 and age <=64:
  print("ADULT")
else:
  print("SENIOR")
# Out:
# Enter your age: 4
# CHILD

# %% [markdown]
# ### Scenario 2

# %%
age = int(input("Enter your age: "))

if age >= 0 and age <=12:
  print("CHILD")
elif age >= 13 and age <=19:
  print("TEENAGER")
elif age >=20 and age <=64:
  print("ADULT")
else:
  print("SENIOR")
# Out:
# Enter your age: 15
# TEENAGER

# %% [markdown]
# ### Scenario 3

# %%
age = int(input("Enter your age: "))

if age >= 0 and age <=12:
  print("CHILD")
elif age >= 13 and age <=19:
  print("TEENAGER")
elif age >=20 and age <=64:
  print("ADULT")
else:
  print("SENIOR")
# Out:
# Enter your age: 25
# ADULT

# %% [markdown]
# ### Q2. Write a Python program that asks the user to enter an email address.
#
#  The program should check if the email contains the characters @ and "." (ignoring case). If either character is present, print "Email format is valid." Otherwise, print "Invalid email format."

# %% [markdown]
# ### Scenario 1

# %%
email = input("Enter your email: ").lower()
if "@" in email and '.' in email:
  print("VALID")
else:
  print("INVALID")
# Out:
# Enter your email: iqraanwar@gmail.com
# VALID

# %% [markdown]
# ### Scenario 2

# %%
email = input("Enter your email: ").lower()
if "@" in email and '.' in email:
  print("VALID")
else:
  print("INVALID")
# Out:
# Enter your email: iqraanwar.com
# INVALID

# %% [markdown]
# ### Q3. Write a Python program that takes three numbers as input and determines the largest among them. Also, check if any or all of the numbers are equal."

# %% [markdown]
# ### Scenario 1

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

if num1 == num2 and num1 == num3 and num2 == num3:
  print("All numbers are equal")
elif num1 > num2 and num1 > num3:
  print("Number 1: ", num1, " is greater thn num2 and num3")
elif num1 ==num3:
  print("num1 is equal to num 3")
elif num2 > num1 and num2 > num3:
  print("Number 2: ", num2, " is greater thn num1 and num3")
elif num3 > num1 and num3 > num2:
  print("Number 3: ", num3, " is greater thn num1 and num2")
# Out:
# Enter number 1: 2
# Enter number 2: 2
# Enter number 3: 2
# All numbers are equal

# %% [markdown]
# ### Scenario 2

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

if num1 == num2 and num1 == num3 and num2 == num3:
  print("All numbers are equal")
elif num1 > num2 and num1 > num3:
  print("Number 1: ", num1, " is greater thn num2 and num3")
elif num1 ==num3:
  print("num1 is equal to num 3")
elif num2 > num1 and num2 > num3:
  print("Number 2: ", num2, " is greater thn num1 and num3")
elif num3 > num1 and num3 > num2:
  print("Number 3: ", num3, " is greater thn num1 and num2")
# Out:
# Enter number 1: 1
# Enter number 2: 2
# Enter number 3: 25
# Number 3:  25  is greater thn num1 and num2

# %% [markdown]
# ### Scenario 3

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

if num1 == num2 and num1 == num3 and num2 == num3:
  print("All numbers are equal")
elif num1 > num2 and num1 > num3:
  print("Number 1: ", num1, " is greater thn num2 and num3")
elif num1 ==num3:
  print("num1 is equal to num 3")
elif num2 > num1 and num2 > num3:
  print("Number 2: ", num2, " is greater thn num1 and num3")
elif num3 > num1 and num3 > num2:
  print("Number 3: ", num3, " is greater thn num1 and num2")
# Out:
# Enter number 1: 25
# Enter number 2: 11
# Enter number 3: 22
# Number 1:  25  is greater thn num2 and num3

# %% [markdown]
# ### Scenario 4

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))
num3 = int(input("Enter number 3: "))

if num1 == num2 and num1 == num3 and num2 == num3:
  print("All numbers are equal")
elif num1 > num2 and num1 > num3:
  print("Number 1: ", num1, " is greater thn num2 and num3")
elif num1 ==num3:
  print("num1 is equal to num 3")
elif num2 > num1 and num2 > num3:
  print("Number 2: ", num2, " is greater thn num1 and num3")
elif num3 > num1 and num3 > num2:
  print("Number 3: ", num3, " is greater thn num1 and num2")
# Out:
# Enter number 1: 11
# Enter number 2: 55
# Enter number 3: 22
# Number 2:  55  is greater thn num1 and num3

# %% [markdown]
# ## Q4. Write a Python program that:
#
# Asks the user to enter a number.
#
# Checks whether the number is positive.
#
# If yes, further check if it's even or odd.
#
# Print "The number is positive and even" if divisible by 2.
#
# Print "The number is positive and odd" if not divisible by 2.
#
# If the number is zero or negative, print "The number is not positive".

# %% [markdown]
# ### Scenario 1

# %%
num1 = int(input("Enter a number: "))
if num1 >=0:
  if num1%2==0:
    print("The number is positive and even.")
  else:
    print("The number is positive and odd")
else:
  print("Negative number.")
# Out:
# Enter a number: 88
# The number is positive and even.

# %% [markdown]
# ### Scenario 2

# %%
num1 = int(input("Enter a number: "))
if num1 >=0:
  if num1%2==0:
    print("The number is positive and even.")
  else:
    print("The number is positive and odd")
else:
  print("Negative number.")
# Out:
# Enter a number: -45
# Negative number.

# %% [markdown]
# ## Q5. Ask the user for a username and password. Check if the username is correct. If it is, then check if the password is correct. If both are correct, print "Access granted".
#
# username = "admin"
#
# password = "1234"

# %% [markdown]
# ### Scenario 1

# %%
username = "admin"
password = "1234"

user = input("Enter your user name: ")
passw = input("Enter your password: ")
if user == username and passw == password:
  print("Access Granted")
else:
  print("Access Denied")
# Out:
# Enter your user name: admin
# Enter your password: 1234
# Access Granted

# %% [markdown]
# ### Scenario 2

# %%
username = "admin"
password = "1234"

user = input("Enter your user name: ")
passw = input("Enter your password: ")
if user == username and passw == password:
  print("Access Granted")
else:
  print("Access Denied")
# Out:
# Enter your user name: dhjs
# Enter your password: dhb
# Access Denied

# %% [markdown]
# ## Q6. Take an integer input from the user and check whether the entered value exists in the tuple my_tuple = (5, 10, 15, 20, 25). Print an appropriate message based on the result.

# %% [markdown]
# ### Scenario 1

# %%
my_tuple = (5, 10, 15, 20, 25)
number = int(input("Enter a number: "))
if number in my_tuple:
  print("The number exists in the tuple.")
else:
  print("The number does not exist in the tuple")
# Out:
# Enter a number: 6
# The number does not exist in the tuple

# %% [markdown]
# ### Scenario 2

# %%
my_tuple = (5, 10, 15, 20, 25)
number = int(input("Enter a number: "))
if number in my_tuple:
  print("The number exists in the tuple.")
else:
  print("The number does not exist in the tuple")
# Out:
# Enter a number: 15
# The number exists in the tuple.

# %% [markdown]
# ## Q7. Create a program that takes the user's first name, last name, and age as input, packs them into a tuple, and prints the tuple.

# %%
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
age = int(input("Enter your age: "))
bio_tuple = (first_name, last_name, age)
print(bio_tuple)
# Out:
# Enter your first name: Iqra
# Enter your last name: Anwar
# Enter your age: 24
# ('Iqra', 'Anwar', 24)

# %% [markdown]
# ## Q8. Given the tuple coordinates = (4, 5, 6), unpack the elements of the tuple into three variables x, y, and z. Then, calculate and print the sum of the variables.

# %%
coordinates = (4, 5, 6)
x,y,z = coordinates
print("x = ",x," y = ",y," z = ",z)
print("The sum of ", x,"+",y,"+",z,"=", x+y+z)
# Out:
# x =  4  y =  5  z =  6
# The sum of  4 + 5 + 6 = 15

# %% [markdown]
# ## Q9. Given the tuple my_tuple = (1, 2, 3, 4, 5), remove the element 3 from the tuple by first converting it to a list, and then print the resulting tuple.

# %%
my_tuple = (1, 2, 3, 4, 5)
tuple_to_list = list(my_tuple)
print("List: ",tuple_to_list)
tuple_to_list.remove(3)
print("Updated data: ",tuple_to_list)
# Out:
# List:  [1, 2, 3, 4, 5]
# Updated data:  [1, 2, 4, 5]

# %% [markdown]
# ## Q10. Given the tuple numbers = (10, 20, 5, 30, 15), find and print the maximum and minimum values in the tuple.

# %%
numbers = (10, 20, 5, 30, 15)
print("The maximum no in the tuple is: ",max(numbers))
print("The minimum no in the tuple is: ",min(numbers))
# Out:
# The maximum no in the tuple is:  30
# The minimum no in the tuple is:  5
