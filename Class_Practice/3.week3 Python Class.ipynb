# %% [markdown]
# # DATA TYPE STRING

# %%
# Concatenation

first_name = 'Iqra'
last_name = 'Anwar'

full_name = first_name + ' ' + last_name
print(full_name)
# Out:
# Iqra Anwar

# %%
employee = 'ali'
age = 2
user_data = employee*age
user_data
# Out:
# 'aliali'

# %%
hello = employee, age
hello
# Out:
# ('ali', 2)

# %%
x = hello *3
x
# Out:
# ('ali', 2, 'ali', 2, 'ali', 2)

# %%
len(x)
# Out:
# 6

# %%
len(employee)
# Out:
# 3

# %%
res = '2 828282'
type(res)
print(len(res))
res[0]
res[1]
res[-1]
# Out:
# 8
# '2'

# %%
flor = 282.3
a = str(flor)
print(a)
a[3]
# Out:
# 282.3
# '.'

# %%
a = '282.3 + 22'

len(a)
# Out:
# 10

# %%
car = 'tesla toyota'
car[8:11]
# Out:
# 'yot'

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
letters = ['P', 'y', 't', 'h', 'o', 'n', 'r','5']
word = ''.join(letters)
print(word)  # Output: Python
# Out:
# Pythonr5

# %%
test = 'we are learning java'
test[:]
# Out:
# 'we are learning java'

# %%
def add(a,b):
  """ adds 2 number
  takes two int, two float, or two str
  """

  return a+b

# %%
add("iqra", "iqra")
# Out:
# 'iqraiqra'

# %%
car = "COROLLA"

car.lower()
# Out:
# 'corolla'

# %%
learn = 'we are learning python, and i love python'
learn.title()
# Out:
# 'We Are Learning Python, And I Love Python'

# %%
learn.swapcase()
# Out:
# 'WE ARE LEARNING PYTHON, AND I LOVE PYTHON'

# %%
car.swapcase()
# Out:
# 'corolla'

# %%
care = 'i dont need them to worry about it.'
care.swapcase()
# Out:
# 'I DONT NEED THEM TO WORRY ABOUT IT.'

# %%
care.capitalize()
# Out:
# 'I dont need them to worry about it.'

# %%
care.count('o')
# Out:
# 4
